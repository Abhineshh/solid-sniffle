# %%
import pandas as pd

# %%
series = pd.Series([1,2,3,4,5])
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
d = [1,2,3,4,5,6]
dindex = ['a','b','c','d','e','f']
series = pd.Series(d, dindex) # assigning my own index
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
d = [[1,2,3],[4,5,6],[7,8,9]]
df = pd.DataFrame(d)
print(df)
print("with custom index")
df = pd.DataFrame(d, index = ['r1','r2','r3'], columns = ['c1','c2','c3']) # custom index and column names
print(df)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9
# with custom index
#     c1  c2  c3
# r1   1   2   3
# r2   4   5   6
# r3   7   8   9

# %% [markdown]
# # Reading Files

# %%
obesity_data = pd.read_csv('obesity_prediction.csv') # reading csv to a dataframe
print(obesity_data.head()) # prints first five rows 
print(obesity_data.tail()) # print last five rows
print(obesity_data.head(2)) # prints custome no. of rows
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# 4  Overweight_Level_II
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 2106  Sometimes    no  1.728139  no  1.676269  0.906247  Sometimes
# 2107  Sometimes    no  2.005130  no  1.341390  0.599270  Sometimes
# 2108  Sometimes    no  2.054193  no  1.414209  0.646288  Sometimes
# 2109  Sometimes    no  2.852339  no  1.139107  0.586035  Sometimes
# 2110  Sometimes    no  2.863513  no  1.026452  0.714137  Sometimes
#
#                      MTRANS           Obesity
# 2106  Public_Transportation  Obesity_Type_III
# 2107  Public_Transportation  Obesity_Type_III
# 2108  Public_Transportation  Obesity_Type_III
# 2109  Public_Transportation  Obesity_Type_III
# 2110  Public_Transportation  Obesity_Type_III
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE       CALC                 MTRANS        Obesity
# 0    no   2.0   no  0.0  1.0         no  Public_Transportation  Normal_Weight
# 1   yes   3.0  yes  3.0  0.0  Sometimes  Public_Transportation  Normal_Weight

# %%
obesity_data.sample(5)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 1578    Male  27.558801  1.801224  119.050381            yes  yes  2.744994
# 275   Female  18.000000  1.500000   50.000000            yes  yes  3.000000
# 222   Female  21.000000  1.720000   66.500000            yes  yes  3.000000
# 80    Female  19.000000  1.630000   58.000000             no   no  3.000000
# 2008  Female  25.999942  1.627483  104.881994            yes  yes  3.000000
#
#       NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE       CALC  \
# 1578  3.0   Sometimes    no  2.478838   no  0.684487  0.677909  Sometimes
# 275   3.0  Frequently    no  2.000000   no  0.000000  1.000000  Sometimes
# 222   4.0      Always    no  3.000000   no  0.000000  2.000000         no
# 80    3.0   Sometimes    no  2.000000  yes  0.000000  0.000000         no
# 2008  3.0   Sometimes    no  2.569364   no  0.159255  0.419446  Sometimes
#
#                      MTRANS           Obesity
# 1578  Public_Transportation   Obesity_Type_II
# 275   Public_Transportation     Normal_Weight
# 222   Public_Transportation     Normal_Weight
# 80    Public_Transportation     Normal_Weight
# 2008  Public_Transportation  Obesity_Type_III

# %% [markdown]
# # Atributes of DataFrame

# %%
print(obesity_data.columns) # Index object with all columns and type
print(list(obesity_data.columns)) #converting ot list
print(obesity_data.columns.tolist()) #converting to list
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history', 'FAVC', 'FCVC',
#        'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS',
#        'Obesity'],
#       dtype='object')
# ['Gender', 'Age', 'Height', 'Weight', 'family_history', 'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS', 'Obesity']
# ['Gender', 'Age', 'Height', 'Weight', 'family_history', 'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS', 'Obesity']

# %%
print(obesity_data.index) # give a RangeIndex object that specifies range of data
print(obesity_data.shape)
print(obesity_data.size)
# print(obesity_data.index.to_list()) # give the list of index
# print(list(obesity_data.index)) # give the list of index
# Out:
# RangeIndex(start=0, stop=2111, step=1)
# (2111, 17)
# 35887

# %%
print(obesity_data.describe()) #give a detailed report of the data
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# 75%       2.477420     1.666678     1.000000
# max       3.000000     3.000000     2.000000

# %%
print(obesity_data.info()) # give the info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          2111 non-null   object
#  1   Age             2111 non-null   float64
#  2   Height          2111 non-null   float64
#  3   Weight          2111 non-null   float64
#  4   family_history  2111 non-null   object
#  5   FAVC            2111 non-null   object
#  6   FCVC            2111 non-null   float64
#  7   NCP             2111 non-null   float64
#  8   CAEC            2111 non-null   object
#  9   SMOKE           2111 non-null   object
#  10  CH2O            2111 non-null   float64
#  11  SCC             2111 non-null   object
#  12  FAF             2111 non-null   float64
#  13  TUE             2111 non-null   float64
#  14  CALC            2111 non-null   object
#  15  MTRANS          2111 non-null   object
#  16  Obesity         2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB
# None

# %% [markdown]
# # Accessing Data

# %% [markdown]
# ## loc:
# - loc helps to list multiple columen and rows at a time
# - it support column name bases indexing/labelling also
# - it also support boolean based indexing

# %%
print(obesity_data.loc[0]) #getting a particular row by index/label
print(obesity_data.loc[0,'Age']) # only a particular column of a specific row
print(obesity_data.loc[0:10, 'Age']) # both start and end are inclusive
print(obesity_data.loc[0:10, ['Age','Height','Weight','Gender']]) # multiple comlumns 
print(obesity_data.loc[[1,4,3,5,24],['Age','Height','Weight','Gender']]) # getting only rows you want 
print(obesity_data.loc[0:5, 'FAVC':'TUE' ]) # getting columns by index
# Out:
# Gender                           Female
# Age                                21.0
# Height                             1.62
# Weight                             64.0
# family_history                      yes
# FAVC                                 no
# FCVC                                2.0
# NCP                                 3.0
# CAEC                          Sometimes
# SMOKE                                no
# CH2O                                2.0
# SCC                                  no
# FAF                                 0.0
# TUE                                 1.0
# CALC                                 no
# MTRANS            Public_Transportation
# Obesity                   Normal_Weight
# Name: 0, dtype: object
# 21.0
# 0     21.0
# 1     21.0
# 2     23.0
# 3     27.0
# 4     22.0
# 5     29.0
# 6     23.0
# 7     22.0
# 8     24.0
# 9     22.0
# 10    26.0
# Name: Age, dtype: float64
#      Age  Height  Weight  Gender
# 0   21.0    1.62    64.0  Female
# 1   21.0    1.52    56.0  Female
# 2   23.0    1.80    77.0    Male
# 3   27.0    1.80    87.0    Male
# 4   22.0    1.78    89.8    Male
# 5   29.0    1.62    53.0    Male
# 6   23.0    1.50    55.0  Female
# 7   22.0    1.64    53.0    Male
# 8   24.0    1.78    64.0    Male
# 9   22.0    1.72    68.0    Male
# 10  26.0    1.85   105.0    Male
#      Age  Height  Weight  Gender
# 1   21.0    1.52    56.0  Female
# 4   22.0    1.78    89.8    Male
# 3   27.0    1.80    87.0    Male
# 5   29.0    1.62    53.0    Male
# 24  21.0    1.85    68.0    Male
#   FAVC  FCVC  NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE
# 0   no   2.0  3.0  Sometimes    no   2.0   no  0.0  1.0
# 1   no   3.0  3.0  Sometimes   yes   3.0  yes  3.0  0.0
# 2   no   2.0  3.0  Sometimes    no   2.0   no  2.0  1.0
# 3   no   3.0  3.0  Sometimes    no   2.0   no  2.0  0.0
# 4   no   2.0  1.0  Sometimes    no   2.0   no  0.0  0.0
# 5  yes   2.0  3.0  Sometimes    no   2.0   no  0.0  0.0

# %% [markdown]
# ## iloc:
# - when we use slicing in iloc the last index is excluded unlike loc
# - in iloc we use index labelling meaning normal integer index, unlike loc where we can use column name(column label)

# %%
print(obesity_data.iloc[0:5,0]) # index '5' is excluded
#  print(obesity_data.iloc[0:5,'Age'] # give error becouse column name labelling is not allowed in iloc
print(obesity_data.iloc[0:5,0:5])
print(obesity_data.loc[[1,4,3,5,24],:])
# Out:
# 0    Female
# 1    Female
# 2      Male
# 3      Male
# 4      Male
# Name: Gender, dtype: object
#    Gender   Age  Height  Weight family_history
# 0  Female  21.0    1.62    64.0            yes
# 1  Female  21.0    1.52    56.0            yes
# 2    Male  23.0    1.80    77.0            yes
# 3    Male  27.0    1.80    87.0             no
# 4    Male  22.0    1.78    89.8             no
#     Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 1   Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 4     Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
# 3     Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 5     Male  29.0    1.62    53.0             no  yes   2.0  3.0  Sometimes
# 24    Male  21.0    1.85    68.0            yes  yes   2.0  3.0  Sometimes
#
#    SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 1    yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 4     no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
# 3     no   2.0   no  2.0  0.0  Frequently                Walking
# 5     no   2.0   no  0.0  0.0   Sometimes             Automobile
# 24    no   2.0   no  0.0  1.0   Sometimes  Public_Transportation
#
#                 Obesity
# 1         Normal_Weight
# 4   Overweight_Level_II
# 3    Overweight_Level_I
# 5         Normal_Weight
# 24        Normal_Weight

# %% [markdown]
# ## Single Value Access:  at , iat
# - slicing is not allowed in at and iat.
# - at is similar to loc and iat to iloc, but slicing is not allowed
# - even lists to access specific rows or columns is not allowed
# - in loc and iloc column label is not mandatory but its mandatory in at and iat

# %%
print(obesity_data.at[0,'Age'])
print(obesity_data.at[4,'Height'])
#   print(obesity_data.iat[0]) # give error
#   print(obesity_data.at[0]) # give error
print(obesity_data.iat[0,2])
# Out:
# 21.0
# 1.78
# 1.62

# %% [markdown]
# ## Accessing with Shorthand(square Brackets) and Dot notation

# %%
obesity_data['Age']
# Out:
# 0       21.000000
# 1       21.000000
# 2       23.000000
# 3       27.000000
# 4       22.000000
#           ...
# 2106    20.976842
# 2107    21.982942
# 2108    22.524036
# 2109    24.361936
# 2110    23.664709
# Name: Age, Length: 2111, dtype: float64

# %%
print(obesity_data[['Age','Height']])
# Out:
#             Age    Height
# 0     21.000000  1.620000
# 1     21.000000  1.520000
# 2     23.000000  1.800000
# 3     27.000000  1.800000
# 4     22.000000  1.780000
# ...         ...       ...
# 2106  20.976842  1.710730
# 2107  21.982942  1.748584
# 2108  22.524036  1.752206
# 2109  24.361936  1.739450
# 2110  23.664709  1.738836
#
# [2111 rows x 2 columns]

# %%
obesity_data.Age
# Out:
# 0       21.000000
# 1       21.000000
# 2       23.000000
# 3       27.000000
# 4       22.000000
#           ...
# 2106    20.976842
# 2107    21.982942
# 2108    22.524036
# 2109    24.361936
# 2110    23.664709
# Name: Age, Length: 2111, dtype: float64

# %% [markdown]
# # Filtering
# - filtering based on condition.
# - we can use loc[] can be used to do this because of its label based indexing and boolean based

# %%
obesity_data.loc[obesity_data['Height'] > 1] # boolean indexing listing height based on a condition
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O  SCC       FAF       TUE        CALC  \
# 0     Sometimes    no  2.000000   no  0.000000  1.000000          no
# 1     Sometimes   yes  3.000000  yes  3.000000  0.000000   Sometimes
# 2     Sometimes    no  2.000000   no  2.000000  1.000000  Frequently
# 3     Sometimes    no  2.000000   no  2.000000  0.000000  Frequently
# 4     Sometimes    no  2.000000   no  0.000000  0.000000   Sometimes
# ...         ...   ...       ...  ...       ...       ...         ...
# 2106  Sometimes    no  1.728139   no  1.676269  0.906247   Sometimes
# 2107  Sometimes    no  2.005130   no  1.341390  0.599270   Sometimes
# 2108  Sometimes    no  2.054193   no  1.414209  0.646288   Sometimes
# 2109  Sometimes    no  2.852339   no  1.139107  0.586035   Sometimes
# 2110  Sometimes    no  2.863513   no  1.026452  0.714137   Sometimes
#
#                      MTRANS              Obesity
# 0     Public_Transportation        Normal_Weight
# 1     Public_Transportation        Normal_Weight
# 2     Public_Transportation        Normal_Weight
# 3                   Walking   Overweight_Level_I
# 4     Public_Transportation  Overweight_Level_II
# ...                     ...                  ...
# 2106  Public_Transportation     Obesity_Type_III
# 2107  Public_Transportation     Obesity_Type_III
# 2108  Public_Transportation     Obesity_Type_III
# 2109  Public_Transportation     Obesity_Type_III
# 2110  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
obesity_data.loc[(obesity_data['Weight'] < 50) & (obesity_data['Height'] > 1.2)]
# Out:
#      Gender        Age    Height     Weight family_history FAVC      FCVC  \
# 36   Female  22.000000  1.560000  49.000000             no  yes  2.000000
# 37   Female  21.000000  1.600000  48.000000             no  yes  2.000000
# 51   Female  20.000000  1.500000  44.000000             no  yes  2.000000
# 60   Female  21.000000  1.550000  49.000000            yes  yes  2.000000
# 75   Female  23.000000  1.630000  45.000000            yes   no  3.000000
# ..      ...        ...       ...        ...            ...  ...       ...
# 737  Female  19.269079  1.580920  44.753943             no   no  3.000000
# 738  Female  19.946244  1.603435  45.000000             no   no  3.000000
# 739  Female  19.639431  1.535350  42.000000             no  yes  3.000000
# 740  Female  19.000000  1.531610  42.000000             no  yes  2.749268
# 741  Female  19.434709  1.525691  42.000000             no  yes  3.000000
#
#           NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE       CALC  \
# 36   3.000000   Sometimes    no  1.000000  yes  2.000000  0.000000         no
# 37   3.000000   Sometimes    no  1.000000   no  1.000000  0.000000  Sometimes
# 51   3.000000   Sometimes    no  1.000000   no  0.000000  0.000000  Sometimes
# 60   3.000000   Sometimes    no  3.000000   no  3.000000  1.000000  Sometimes
# 75   3.000000   Sometimes    no  3.000000  yes  2.000000  0.000000         no
# ..        ...         ...   ...       ...  ...       ...       ...        ...
# 737  2.975362  Frequently    no  1.246822  yes  0.979701  0.000000  Sometimes
# 738  3.000000  Frequently    no  2.487919  yes  1.230441  0.000000  Sometimes
# 739  1.000000  Frequently    no  1.496810   no  0.000000  0.513427  Sometimes
# 740  1.394539  Frequently    no  1.322048   no  0.463949  0.800993  Sometimes
# 741  1.000000  Frequently    no  1.764055   no  0.000000  0.560887  Sometimes
#
#                     MTRANS              Obesity
# 36                 Walking        Normal_Weight
# 37   Public_Transportation        Normal_Weight
# 51              Automobile        Normal_Weight
# 60   Public_Transportation        Normal_Weight
# 75   Public_Transportation  Insufficient_Weight
# ..                     ...                  ...
# 737  Public_Transportation  Insufficient_Weight
# 738  Public_Transportation  Insufficient_Weight
# 739  Public_Transportation  Insufficient_Weight
# 740  Public_Transportation  Insufficient_Weight
# 741  Public_Transportation  Insufficient_Weight
#
# [140 rows x 17 columns]

# %%
obesity_data.loc[(obesity_data['Weight'] < 50) | (obesity_data['Height'] > 1.2)]
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O  SCC       FAF       TUE        CALC  \
# 0     Sometimes    no  2.000000   no  0.000000  1.000000          no
# 1     Sometimes   yes  3.000000  yes  3.000000  0.000000   Sometimes
# 2     Sometimes    no  2.000000   no  2.000000  1.000000  Frequently
# 3     Sometimes    no  2.000000   no  2.000000  0.000000  Frequently
# 4     Sometimes    no  2.000000   no  0.000000  0.000000   Sometimes
# ...         ...   ...       ...  ...       ...       ...         ...
# 2106  Sometimes    no  1.728139   no  1.676269  0.906247   Sometimes
# 2107  Sometimes    no  2.005130   no  1.341390  0.599270   Sometimes
# 2108  Sometimes    no  2.054193   no  1.414209  0.646288   Sometimes
# 2109  Sometimes    no  2.852339   no  1.139107  0.586035   Sometimes
# 2110  Sometimes    no  2.863513   no  1.026452  0.714137   Sometimes
#
#                      MTRANS              Obesity
# 0     Public_Transportation        Normal_Weight
# 1     Public_Transportation        Normal_Weight
# 2     Public_Transportation        Normal_Weight
# 3                   Walking   Overweight_Level_I
# 4     Public_Transportation  Overweight_Level_II
# ...                     ...                  ...
# 2106  Public_Transportation     Obesity_Type_III
# 2107  Public_Transportation     Obesity_Type_III
# 2108  Public_Transportation     Obesity_Type_III
# 2109  Public_Transportation     Obesity_Type_III
# 2110  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %% [markdown]
# ### we can also doe filtering  using the [] and dot notation

# %%
obesity_data[(obesity_data['Weight'] < 50) & (obesity_data['Height'] > 1.2)]
# Out:
#      Gender        Age    Height     Weight family_history FAVC      FCVC  \
# 36   Female  22.000000  1.560000  49.000000             no  yes  2.000000
# 37   Female  21.000000  1.600000  48.000000             no  yes  2.000000
# 51   Female  20.000000  1.500000  44.000000             no  yes  2.000000
# 60   Female  21.000000  1.550000  49.000000            yes  yes  2.000000
# 75   Female  23.000000  1.630000  45.000000            yes   no  3.000000
# ..      ...        ...       ...        ...            ...  ...       ...
# 737  Female  19.269079  1.580920  44.753943             no   no  3.000000
# 738  Female  19.946244  1.603435  45.000000             no   no  3.000000
# 739  Female  19.639431  1.535350  42.000000             no  yes  3.000000
# 740  Female  19.000000  1.531610  42.000000             no  yes  2.749268
# 741  Female  19.434709  1.525691  42.000000             no  yes  3.000000
#
#           NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE       CALC  \
# 36   3.000000   Sometimes    no  1.000000  yes  2.000000  0.000000         no
# 37   3.000000   Sometimes    no  1.000000   no  1.000000  0.000000  Sometimes
# 51   3.000000   Sometimes    no  1.000000   no  0.000000  0.000000  Sometimes
# 60   3.000000   Sometimes    no  3.000000   no  3.000000  1.000000  Sometimes
# 75   3.000000   Sometimes    no  3.000000  yes  2.000000  0.000000         no
# ..        ...         ...   ...       ...  ...       ...       ...        ...
# 737  2.975362  Frequently    no  1.246822  yes  0.979701  0.000000  Sometimes
# 738  3.000000  Frequently    no  2.487919  yes  1.230441  0.000000  Sometimes
# 739  1.000000  Frequently    no  1.496810   no  0.000000  0.513427  Sometimes
# 740  1.394539  Frequently    no  1.322048   no  0.463949  0.800993  Sometimes
# 741  1.000000  Frequently    no  1.764055   no  0.000000  0.560887  Sometimes
#
#                     MTRANS              Obesity
# 36                 Walking        Normal_Weight
# 37   Public_Transportation        Normal_Weight
# 51              Automobile        Normal_Weight
# 60   Public_Transportation        Normal_Weight
# 75   Public_Transportation  Insufficient_Weight
# ..                     ...                  ...
# 737  Public_Transportation  Insufficient_Weight
# 738  Public_Transportation  Insufficient_Weight
# 739  Public_Transportation  Insufficient_Weight
# 740  Public_Transportation  Insufficient_Weight
# 741  Public_Transportation  Insufficient_Weight
#
# [140 rows x 17 columns]

# %%
obesity_data[(obesity_data['Weight'] < 50) | (obesity_data['Height'] > 1.2)]
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O  SCC       FAF       TUE        CALC  \
# 0     Sometimes    no  2.000000   no  0.000000  1.000000          no
# 1     Sometimes   yes  3.000000  yes  3.000000  0.000000   Sometimes
# 2     Sometimes    no  2.000000   no  2.000000  1.000000  Frequently
# 3     Sometimes    no  2.000000   no  2.000000  0.000000  Frequently
# 4     Sometimes    no  2.000000   no  0.000000  0.000000   Sometimes
# ...         ...   ...       ...  ...       ...       ...         ...
# 2106  Sometimes    no  1.728139   no  1.676269  0.906247   Sometimes
# 2107  Sometimes    no  2.005130   no  1.341390  0.599270   Sometimes
# 2108  Sometimes    no  2.054193   no  1.414209  0.646288   Sometimes
# 2109  Sometimes    no  2.852339   no  1.139107  0.586035   Sometimes
# 2110  Sometimes    no  2.863513   no  1.026452  0.714137   Sometimes
#
#                      MTRANS              Obesity
# 0     Public_Transportation        Normal_Weight
# 1     Public_Transportation        Normal_Weight
# 2     Public_Transportation        Normal_Weight
# 3                   Walking   Overweight_Level_I
# 4     Public_Transportation  Overweight_Level_II
# ...                     ...                  ...
# 2106  Public_Transportation     Obesity_Type_III
# 2107  Public_Transportation     Obesity_Type_III
# 2108  Public_Transportation     Obesity_Type_III
# 2109  Public_Transportation     Obesity_Type_III
# 2110  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %% [markdown]
# # Regular Expressions

# %%
obesity_data.loc[obesity_data['Obesity'].str.contains('Normal')]
# Out:
#      Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0    Female  21.0    1.62    64.0            yes   no   2.0  3.0   Sometimes
# 1    Female  21.0    1.52    56.0            yes   no   3.0  3.0   Sometimes
# 2      Male  23.0    1.80    77.0            yes   no   2.0  3.0   Sometimes
# 5      Male  29.0    1.62    53.0             no  yes   2.0  3.0   Sometimes
# 6    Female  23.0    1.50    55.0            yes  yes   3.0  3.0   Sometimes
# ..      ...   ...     ...     ...            ...  ...   ...  ...         ...
# 491    Male  25.0    1.66    68.0             no  yes   2.0  3.0   Sometimes
# 493    Male  20.0    1.80    65.0             no  yes   2.0  3.0  Frequently
# 494  Female  18.0    1.67    66.0             no  yes   3.0  3.0   Sometimes
# 495    Male  19.0    1.80    60.0            yes  yes   3.0  1.0      Always
# 497    Male  20.0    1.56    45.0             no   no   2.0  3.0   Sometimes
#
#     SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0      no   2.0   no  0.0  1.0          no  Public_Transportation
# 1     yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2      no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 5      no   2.0   no  0.0  0.0   Sometimes             Automobile
# 6      no   2.0   no  1.0  0.0   Sometimes              Motorbike
# ..    ...   ...  ...  ...  ...         ...                    ...
# 491   yes   1.0   no  1.0  1.0   Sometimes  Public_Transportation
# 493    no   1.0   no  2.0  0.0   Sometimes              Motorbike
# 494    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
# 495    no   1.0  yes  0.0  0.0          no              Motorbike
# 497    no   2.0   no  1.0  1.0   Sometimes  Public_Transportation
#
#            Obesity
# 0    Normal_Weight
# 1    Normal_Weight
# 2    Normal_Weight
# 5    Normal_Weight
# 6    Normal_Weight
# ..             ...
# 491  Normal_Weight
# 493  Normal_Weight
# 494  Normal_Weight
# 495  Normal_Weight
# 497  Normal_Weight
#
# [287 rows x 17 columns]

# %%
obesity_data.loc[~(obesity_data['Obesity'].str.startswith('Normal'))]
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# 10      Male  26.000000  1.850000  105.000000            yes  yes   3.0  3.0
# 11    Female  21.000000  1.720000   80.000000            yes  yes   2.0  3.0
# 13      Male  41.000000  1.800000   99.000000             no  yes   2.0  3.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#             CAEC SMOKE      CH2O  SCC       FAF       TUE        CALC  \
# 3      Sometimes    no  2.000000   no  2.000000  0.000000  Frequently
# 4      Sometimes    no  2.000000   no  0.000000  0.000000   Sometimes
# 10    Frequently    no  3.000000   no  2.000000  2.000000   Sometimes
# 11    Frequently    no  2.000000  yes  2.000000  1.000000   Sometimes
# 13     Sometimes    no  2.000000   no  2.000000  1.000000  Frequently
# ...          ...   ...       ...  ...       ...       ...         ...
# 2106   Sometimes    no  1.728139   no  1.676269  0.906247   Sometimes
# 2107   Sometimes    no  2.005130   no  1.341390  0.599270   Sometimes
# 2108   Sometimes    no  2.054193   no  1.414209  0.646288   Sometimes
# 2109   Sometimes    no  2.852339   no  1.139107  0.586035   Sometimes
# 2110   Sometimes    no  2.863513   no  1.026452  0.714137   Sometimes
#
#                      MTRANS              Obesity
# 3                   Walking   Overweight_Level_I
# 4     Public_Transportation  Overweight_Level_II
# 10    Public_Transportation       Obesity_Type_I
# 11    Public_Transportation  Overweight_Level_II
# 13               Automobile       Obesity_Type_I
# ...                     ...                  ...
# 2106  Public_Transportation     Obesity_Type_III
# 2107  Public_Transportation     Obesity_Type_III
# 2108  Public_Transportation     Obesity_Type_III
# 2109  Public_Transportation     Obesity_Type_III
# 2110  Public_Transportation     Obesity_Type_III
#
# [1824 rows x 17 columns]

# %%
obesity_data[~(obesity_data['Obesity'].str.startswith('Normal'))] # can do without loc[] also
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# 10      Male  26.000000  1.850000  105.000000            yes  yes   3.0  3.0
# 11    Female  21.000000  1.720000   80.000000            yes  yes   2.0  3.0
# 13      Male  41.000000  1.800000   99.000000             no  yes   2.0  3.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#             CAEC SMOKE      CH2O  SCC       FAF       TUE        CALC  \
# 3      Sometimes    no  2.000000   no  2.000000  0.000000  Frequently
# 4      Sometimes    no  2.000000   no  0.000000  0.000000   Sometimes
# 10    Frequently    no  3.000000   no  2.000000  2.000000   Sometimes
# 11    Frequently    no  2.000000  yes  2.000000  1.000000   Sometimes
# 13     Sometimes    no  2.000000   no  2.000000  1.000000  Frequently
# ...          ...   ...       ...  ...       ...       ...         ...
# 2106   Sometimes    no  1.728139   no  1.676269  0.906247   Sometimes
# 2107   Sometimes    no  2.005130   no  1.341390  0.599270   Sometimes
# 2108   Sometimes    no  2.054193   no  1.414209  0.646288   Sometimes
# 2109   Sometimes    no  2.852339   no  1.139107  0.586035   Sometimes
# 2110   Sometimes    no  2.863513   no  1.026452  0.714137   Sometimes
#
#                      MTRANS              Obesity
# 3                   Walking   Overweight_Level_I
# 4     Public_Transportation  Overweight_Level_II
# 10    Public_Transportation       Obesity_Type_I
# 11    Public_Transportation  Overweight_Level_II
# 13               Automobile       Obesity_Type_I
# ...                     ...                  ...
# 2106  Public_Transportation     Obesity_Type_III
# 2107  Public_Transportation     Obesity_Type_III
# 2108  Public_Transportation     Obesity_Type_III
# 2109  Public_Transportation     Obesity_Type_III
# 2110  Public_Transportation     Obesity_Type_III
#
# [1824 rows x 17 columns]

# %% [markdown]
# # Updating and Modification
#
# - ### every modification applies to the original dataframs itself and not the file
# - ## we can use
# - - loc
#   - iloc
#   - at
#   - iat

# %%
obesity_data.loc[:, 'family_history'] = 'no' # changing everyone family history to no
obesity_data.sample(5)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 956     Male  22.766227  1.874061   89.754302             no  yes  2.000000
# 318   Female  25.000000  1.560000   45.000000             no  yes  2.000000
# 1000  Female  25.461411  1.700000   78.055968             no  yes  2.661556
# 891   Female  20.901393  1.709585   75.000000             no  yes  2.104105
# 1924  Female  21.704699  1.787614  137.858254             no  yes  3.000000
#
#            NCP       CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 956   2.870005  Sometimes    no  1.150310  no  0.417724  1.000000  Sometimes
# 318   3.000000  Sometimes    no  1.000000  no  0.000000  0.000000  Sometimes
# 1000  3.000000  Sometimes    no  3.000000  no  0.551810  0.658783  Sometimes
# 891   3.000000  Sometimes    no  1.871033  no  1.000000  0.000000  Sometimes
# 1924  3.000000  Sometimes    no  2.531456  no  1.980738  0.835771  Sometimes
#
#                      MTRANS              Obesity
# 956              Automobile   Overweight_Level_I
# 318   Public_Transportation        Normal_Weight
# 1000  Public_Transportation  Overweight_Level_II
# 891   Public_Transportation   Overweight_Level_I
# 1924  Public_Transportation     Obesity_Type_III

# %%
obesity_data.loc[[1,4,3,5,24],['Age','Height','Weight','Gender']] = (20, 1.79, 105, 'Male')
obesity_data.loc[[1,4,3,5,24],['Age','Height','Weight','Gender']]
#   obesity_data[[1,4,3,5,24],['Age','Height','Weight','Gender']] # this wont work as shorthand doesnot accept a more than two parameters
# Out:
#      Age  Height  Weight Gender
# 1   20.0    1.79   105.0   Male
# 4   20.0    1.79   105.0   Male
# 3   20.0    1.79   105.0   Male
# 5   20.0    1.79   105.0   Male
# 24  20.0    1.79   105.0   Male

# %%
obesity_data.iloc[[3,5,24],[2,3,4]] = (1.79, 75, 'yes')
obesity_data.iloc[[3,5,24],[2,3,4]]
# Out:
#     Height  Weight family_history
# 3     1.79    75.0            yes
# 5     1.79    75.0            yes
# 24    1.79    75.0            yes

# %%
obesity_data['family_history'] = 'yes'
obesity_data['family_history']
# Out:
# 0       yes
# 1       yes
# 2       yes
# 3       yes
# 4       yes
#        ...
# 2106    yes
# 2107    yes
# 2108    yes
# 2109    yes
# 2110    yes
# Name: family_history, Length: 2111, dtype: object

# %% [markdown]
# # Transformations
# ## Apply() give a new dataframe with the applied changes and does not change the original dataframe

# %%
def increment_by_5(x):
    return x + 5
def decrement_by_5(x):
    return x - 5


obesity_data['Age'] = obesity_data['Age'].apply(increment_by_5)
print(obesity_data['Age'])
obesity_data['Age'] = obesity_data['Age'].apply(decrement_by_5)
print(obesity_data['Age'])
# Out:
# 0       26.000000
# 1       25.000000
# 2       28.000000
# 3       25.000000
# 4       25.000000
#           ...
# 2106    25.976842
# 2107    26.982942
# 2108    27.524036
# 2109    29.361936
# 2110    28.664709
# Name: Age, Length: 2111, dtype: float64
# 0       21.000000
# 1       20.000000
# 2       23.000000
# 3       20.000000
# 4       20.000000
#           ...
# 2106    20.976842
# 2107    21.982942
# 2108    22.524036
# 2109    24.361936
# 2110    23.664709
# Name: Age, Length: 2111, dtype: float64

# %% [markdown]
# ### lambda function with apply()

# %%
obesity_data['Age'] = obesity_data['Age'].apply(lambda x: x - 5)
print(obesity_data['Age'])
# Out:
# 0       16.000000
# 1       15.000000
# 2       18.000000
# 3       15.000000
# 4       15.000000
#           ...
# 2106    15.976842
# 2107    16.982942
# 2108    17.524036
# 2109    19.361936
# 2110    18.664709
# Name: Age, Length: 2111, dtype: float64

# %% [markdown]
# # Creating a new column

# %%
def ageCategoriser(x):
    if x in range(20,26):
        return 'Young Adult'
    elif x in range(26,30):
        return 'Adult'
    elif x < 20:
        return 'Child'
    else:
        return 'Old'

obesity_data['Age Category'] = obesity_data['Age'].apply(ageCategoriser)
print(obesity_data.sample(10))
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 249     Male  16.000000  1.760000   78.000000            yes  yes  3.000000
# 196     Male  17.000000  1.750000   74.000000            yes   no  2.000000
# 1161    Male  13.181821  1.662669   79.863546            yes   no  2.492758
# 1783    Male  18.881938  1.829971  121.041720            yes  yes  2.684335
# 574   Female  14.833682  1.699464   49.676046            yes  yes  1.270448
# 233   Female  29.000000  1.680000   77.000000            yes   no  3.000000
# 1308    Male  18.000000  1.735659   93.429205            yes  yes  2.000000
# 1035    Male  12.971574  1.720379   85.000000            yes  yes  2.000000
# 2031  Female  21.000000  1.634894  111.946321            yes  yes  3.000000
# 900   Female  16.000000  1.618148   68.981403            yes  yes  1.142468
#
#            NCP        CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 249   1.000000   Sometimes    no  2.000000  no  3.000000  0.000000  Sometimes
# 196   3.000000   Sometimes    no  2.000000  no  1.000000  2.000000  Sometimes
# 1161  2.270163   Sometimes    no  1.992586  no  1.452467  0.864583         no
# 1783  2.711238   Sometimes    no  2.732331  no  1.156024  0.442456  Sometimes
# 574   3.731212  Frequently    no  1.876915  no  2.000000  1.000000  Sometimes
# 233   1.000000   Sometimes    no  2.000000  no  1.000000  0.000000  Sometimes
# 1308  3.000000   Sometimes    no  1.249307  no  0.973465  1.000000         no
# 1035  3.000000   Sometimes    no  2.802498  no  1.000000  0.417580  Sometimes
# 2031  3.000000   Sometimes    no  2.737353  no  0.000000  0.076094  Sometimes
# 900   3.000000          no    no  2.197732  no  0.827506  0.572877  Sometimes
#
#                      MTRANS              Obesity Age Category
# 249                 Walking   Overweight_Level_I        Child
# 196                    Bike        Normal_Weight        Child
# 1161  Public_Transportation  Overweight_Level_II        Child
# 1783  Public_Transportation      Obesity_Type_II        Child
# 574   Public_Transportation  Insufficient_Weight        Child
# 233              Automobile  Overweight_Level_II        Adult
# 1308  Public_Transportation       Obesity_Type_I        Child
# 1035  Public_Transportation  Overweight_Level_II        Child
# 2031  Public_Transportation     Obesity_Type_III  Young Adult
# 900   Public_Transportation   Overweight_Level_I        Child

# %% [markdown]
# ### Pandas is built on top of numpy so it will work smoothly with numpy

# %% [markdown]
# ### we can use numpy's Vectorize for transformations and creating a new column

# %%
import numpy as np

obesity_data['Whether Teen'] = np.where( (obesity_data['Age'] >=13) & (obesity_data['Age'] <= 19), 'yes', 'no' )
obesity_data.sample(20)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 2025  Female  16.394047  1.792933  137.832414            yes  yes  3.000000
# 237   Female  14.000000  1.640000   53.000000            yes  yes  3.000000
# 680     Male  15.242237  1.756330   54.567343            yes  yes  2.000000
# 871     Male  18.801436  1.855779   86.098523            yes  yes  2.000000
# 1795    Male  15.068432  1.657132  105.580491            yes  yes  2.724121
# 17    Female  24.000000  1.530000   78.000000            yes  yes  2.000000
# 971     Male  14.506389  1.824449   87.656029            yes  yes  2.793561
# 114   Female  14.000000  1.610000   62.000000            yes  yes  3.000000
# 134     Male  25.000000  1.770000  109.000000            yes  yes  3.000000
# 812     Male  14.216380  1.812472   86.748295            yes  yes  2.000000
# 1912  Female  14.529746  1.751038  133.843033            yes  yes  3.000000
# 428     Male  18.000000  1.700000   69.000000            yes  yes  3.000000
# 597     Male  13.000000  1.710800   50.925380            yes  yes  2.000000
# 1805  Female  20.902283  1.678658  104.954834            yes  yes  3.000000
# 1135  Female  16.959940  1.483284   62.894283            yes   no  2.000000
# 2057  Female  21.000000  1.632983  111.157811            yes  yes  3.000000
# 1881  Female  19.475242  1.694726  112.776612            yes  yes  3.000000
# 1964  Female  15.801791  1.721476  131.042274            yes  yes  3.000000
# 1139    Male  17.087056  1.792435   89.998729            yes  yes  1.904732
# 286   Female  16.000000  1.600000   61.000000            yes  yes  2.000000
#
#            NCP        CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 2025  3.000000   Sometimes    no  2.682909  no  1.318743  0.900497
# 237   3.000000   Sometimes    no  1.000000  no  1.000000  1.000000
# 680   3.985250   Sometimes    no  2.654078  no  2.113151  2.000000
# 871   2.372339   Sometimes    no  1.675733  no  1.066241  1.000000
# 1795  1.437959   Sometimes    no  1.590418  no  0.029603  1.122118
# 17    1.000000   Sometimes    no  2.000000  no  0.000000  0.000000
# 971   3.788602   Sometimes    no  2.429059  no  2.094542  0.393358
# 114   1.000000  Frequently    no  2.000000  no  1.000000  0.000000
# 134   3.000000   Sometimes    no  1.000000  no  2.000000  0.000000
# 812   3.000000   Sometimes    no  2.168651  no  0.977998  0.142638
# 1912  3.000000   Sometimes    no  2.955075  no  1.460460  0.655558
# 428   1.000000  Frequently    no  1.000000  no  2.000000  1.000000
# 597   3.000000   Sometimes    no  2.000000  no  0.000000  1.593704
# 1805  3.000000   Sometimes    no  1.666160  no  0.210351  0.734210
# 1135  1.680838   Sometimes    no  1.833635  no  0.281876  0.575848
# 2057  3.000000   Sometimes    no  2.638896  no  0.000000  0.224559
# 1881  3.000000   Sometimes    no  2.724099  no  0.336795  0.153462
# 1964  3.000000   Sometimes    no  1.837184  no  1.525165  0.926443
# 1139  2.608416   Sometimes    no  1.204175  no  0.000000  1.895312
# 286   3.000000   Sometimes    no  1.000000  no  1.000000  1.000000
#
#             CALC                 MTRANS              Obesity Age Category  \
# 2025   Sometimes  Public_Transportation     Obesity_Type_III        Child
# 237           no  Public_Transportation        Normal_Weight        Child
# 680           no  Public_Transportation  Insufficient_Weight        Child
# 871    Sometimes             Automobile   Overweight_Level_I        Child
# 1795          no  Public_Transportation      Obesity_Type_II        Child
# 17            no             Automobile       Obesity_Type_I  Young Adult
# 971    Sometimes  Public_Transportation   Overweight_Level_I        Child
# 114   Frequently  Public_Transportation        Normal_Weight        Child
# 134    Sometimes             Automobile       Obesity_Type_I  Young Adult
# 812    Sometimes  Public_Transportation   Overweight_Level_I        Child
# 1912   Sometimes  Public_Transportation     Obesity_Type_III        Child
# 428    Sometimes  Public_Transportation        Normal_Weight        Child
# 597    Sometimes  Public_Transportation  Insufficient_Weight        Child
# 1805   Sometimes  Public_Transportation     Obesity_Type_III          Old
# 1135          no  Public_Transportation  Overweight_Level_II        Child
# 2057   Sometimes  Public_Transportation     Obesity_Type_III  Young Adult
# 1881   Sometimes  Public_Transportation     Obesity_Type_III        Child
# 1964   Sometimes  Public_Transportation     Obesity_Type_III        Child
# 1139   Sometimes  Public_Transportation  Overweight_Level_II        Child
# 286    Sometimes  Public_Transportation        Normal_Weight        Child
#
#      Whether Teen
# 2025          yes
# 237           yes
# 680           yes
# 871           yes
# 1795          yes
# 17             no
# 971           yes
# 114           yes
# 134            no
# 812           yes
# 1912          yes
# 428           yes
# 597           yes
# 1805           no
# 1135          yes
# 2057           no
# 1881           no
# 1964          yes
# 1139          yes
# 286           yes

# %% [markdown]
# # insertion

# %%
obesity_data.insert(2, 'BMI', 20) # create new column at index 2 with 20 as its values
obesity_data.head()
# Out:
#    Gender   Age  BMI  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female  16.0   20    1.62    64.0            yes   no   2.0  3.0
# 1    Male  15.0   20    1.79   105.0            yes   no   3.0  3.0
# 2    Male  18.0   20    1.80    77.0            yes   no   2.0  3.0
# 3    Male  15.0   20    1.79    75.0            yes   no   3.0  3.0
# 4    Male  15.0   20    1.79   105.0            yes   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity Age Category Whether Teen
# 0        Normal_Weight        Child          yes
# 1        Normal_Weight        Child          yes
# 2        Normal_Weight        Child          yes
# 3   Overweight_Level_I        Child          yes
# 4  Overweight_Level_II        Child          yes

# %% [markdown]
# ### Deleting a column

# %%
# obesity_data.drop(columns = 'BMI') # This wont change the dataframe
# obesity_data.drop(columns = 'BMI', inplace = True) # this will
obesity_data = obesity_data.drop(columns = 'BMI') # even this will
obesity_data.sample(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 3
#       1 # obesity_data.drop(columns = 'BMI') # This wont change the dataframe
#       2 # obesity_data.drop(columns = 'BMI', inplace = True) # this will
# ----> 3 obesity_data = obesity_data.drop(columns = 'BMI') # even this will
#       4 obesity_data.sample(5)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['BMI'] not found in axis"

# %%
# insertion with calculation and relativity
obesity_data.insert(2, 'BMI',(obesity_data['Weight']/obesity_data['Height']**2))

# %%
obesity_data.head()
# Out:
#    Gender   Age        BMI  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female  16.0  24.386526    1.62    64.0            yes   no   2.0  3.0
# 1    Male  15.0  32.770513    1.79   105.0            yes   no   3.0  3.0
# 2    Male  18.0  23.765432    1.80    77.0            yes   no   2.0  3.0
# 3    Male  15.0  23.407509    1.79    75.0            yes   no   3.0  3.0
# 4    Male  15.0  32.770513    1.79   105.0            yes   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity Age Category Whether Teen
# 0        Normal_Weight        Child          yes
# 1        Normal_Weight        Child          yes
# 2        Normal_Weight        Child          yes
# 3   Overweight_Level_I        Child          yes
# 4  Overweight_Level_II        Child          yes

# %%
obesity_data = obesity_data.drop(columns = 'BMI') # deleting bmi

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  16.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1    Male  15.0    1.79   105.0            yes   no   3.0  3.0  Sometimes
# 2    Male  18.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  15.0    1.79    75.0            yes   no   3.0  3.0  Sometimes
# 4    Male  15.0    1.79   105.0            yes   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity Age Category Whether Teen
# 0        Normal_Weight        Child          yes
# 1        Normal_Weight        Child          yes
# 2        Normal_Weight        Child          yes
# 3   Overweight_Level_I        Child          yes
# 4  Overweight_Level_II        Child          yes

# %% [markdown]
# ### droping multiple columns

# %%
# creating to demonstrate deleting multiple values
obesity_data.insert(2, 'BMI',(obesity_data['Weight']/obesity_data['Height']**2))
obesity_data.insert(2, 'BMI newer', 20)

# %%
obesity_data.head()
# Out:
#    Gender   Age  BMI newer        BMI  Height  Weight family_history FAVC  \
# 0  Female  16.0         20  24.386526    1.62    64.0            yes   no
# 1    Male  15.0         20  32.770513    1.79   105.0            yes   no
# 2    Male  18.0         20  23.765432    1.80    77.0            yes   no
# 3    Male  15.0         20  23.407509    1.79    75.0            yes   no
# 4    Male  15.0         20  32.770513    1.79   105.0            yes   no
#
#    FCVC  NCP  ... SMOKE CH2O  SCC  FAF  TUE        CALC  \
# 0   2.0  3.0  ...    no  2.0   no  0.0  1.0          no
# 1   3.0  3.0  ...   yes  3.0  yes  3.0  0.0   Sometimes
# 2   2.0  3.0  ...    no  2.0   no  2.0  1.0  Frequently
# 3   3.0  3.0  ...    no  2.0   no  2.0  0.0  Frequently
# 4   2.0  1.0  ...    no  2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS              Obesity Age Category Whether Teen
# 0  Public_Transportation        Normal_Weight        Child          yes
# 1  Public_Transportation        Normal_Weight        Child          yes
# 2  Public_Transportation        Normal_Weight        Child          yes
# 3                Walking   Overweight_Level_I        Child          yes
# 4  Public_Transportation  Overweight_Level_II        Child          yes
#
# [5 rows x 21 columns]

# %%
obesity_data.drop(columns=['BMI','BMI newer'], inplace = True)

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  16.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1    Male  15.0    1.79   105.0            yes   no   3.0  3.0  Sometimes
# 2    Male  18.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  15.0    1.79    75.0            yes   no   3.0  3.0  Sometimes
# 4    Male  15.0    1.79   105.0            yes   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity Age Category Whether Teen
# 0        Normal_Weight        Child          yes
# 1        Normal_Weight        Child          yes
# 2        Normal_Weight        Child          yes
# 3   Overweight_Level_I        Child          yes
# 4  Overweight_Level_II        Child          yes

# %% [markdown]
# # Deleting columns without pandas function

# %%
del obesity_data['CAEC']

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP SMOKE  CH2O  \
# 0  Female  16.0    1.62    64.0            yes   no   2.0  3.0    no   2.0
# 1    Male  15.0    1.79   105.0            yes   no   3.0  3.0   yes   3.0
# 2    Male  18.0    1.80    77.0            yes   no   2.0  3.0    no   2.0
# 3    Male  15.0    1.79    75.0            yes   no   3.0  3.0    no   2.0
# 4    Male  15.0    1.79   105.0            yes   no   2.0  1.0    no   2.0
#
#    SCC  FAF  TUE        CALC                 MTRANS              Obesity  \
# 0   no  0.0  1.0          no  Public_Transportation        Normal_Weight
# 1  yes  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight
# 2   no  2.0  1.0  Frequently  Public_Transportation        Normal_Weight
# 3   no  2.0  0.0  Frequently                Walking   Overweight_Level_I
# 4   no  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II
#
#   Age Category Whether Teen
# 0        Child          yes
# 1        Child          yes
# 2        Child          yes
# 3        Child          yes
# 4        Child          yes

# %% [markdown]
# # Renaming Columns

# %%
obesity_data.rename(columns= {'Whether Teen': 'is Teen'}) # will not change the og dataframe
obesity_data.rename(columns = {'Whether Teen': 'is Teen'}, inplace = True) # this will
print(obesity_data.head())
obesity_data = obesity_data.rename(columns = {'is Teen': 'Whether Teen'}) # this will
print(obesity_data.head())
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP SMOKE  CH2O  \
# 0  Female  16.0    1.62    64.0            yes   no   2.0  3.0    no   2.0
# 1    Male  15.0    1.79   105.0            yes   no   3.0  3.0   yes   3.0
# 2    Male  18.0    1.80    77.0            yes   no   2.0  3.0    no   2.0
# 3    Male  15.0    1.79    75.0            yes   no   3.0  3.0    no   2.0
# 4    Male  15.0    1.79   105.0            yes   no   2.0  1.0    no   2.0
#
#    SCC  FAF  TUE        CALC                 MTRANS              Obesity  \
# 0   no  0.0  1.0          no  Public_Transportation        Normal_Weight
# 1  yes  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight
# 2   no  2.0  1.0  Frequently  Public_Transportation        Normal_Weight
# 3   no  2.0  0.0  Frequently                Walking   Overweight_Level_I
# 4   no  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II
#
#   Age Category is Teen
# 0        Child     yes
# 1        Child     yes
# 2        Child     yes
# 3        Child     yes
# 4        Child     yes
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP SMOKE  CH2O  \
# 0  Female  16.0    1.62    64.0            yes   no   2.0  3.0    no   2.0
# 1    Male  15.0    1.79   105.0            yes   no   3.0  3.0   yes   3.0
# 2    Male  18.0    1.80    77.0            yes   no   2.0  3.0    no   2.0
# 3    Male  15.0    1.79    75.0            yes   no   3.0  3.0    no   2.0
# 4    Male  15.0    1.79   105.0            yes   no   2.0  1.0    no   2.0
#
#    SCC  FAF  TUE        CALC                 MTRANS              Obesity  \
# 0   no  0.0  1.0          no  Public_Transportation        Normal_Weight
# 1  yes  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight
# 2   no  2.0  1.0  Frequently  Public_Transportation        Normal_Weight
# 3   no  2.0  0.0  Frequently                Walking   Overweight_Level_I
# 4   no  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II
#
#   Age Category Whether Teen
# 0        Child          yes
# 1        Child          yes
# 2        Child          yes
# 3        Child          yes
# 4        Child          yes

# %% [markdown]
# ### renaming Multiple columns

# %%
obesity_data.rename(columns = {'Whether Teen': 'is Teen', 'Age Category': 'Age Group'}, inplace = True)

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP SMOKE  CH2O  \
# 0  Female  16.0    1.62    64.0            yes   no   2.0  3.0    no   2.0
# 1    Male  15.0    1.79   105.0            yes   no   3.0  3.0   yes   3.0
# 2    Male  18.0    1.80    77.0            yes   no   2.0  3.0    no   2.0
# 3    Male  15.0    1.79    75.0            yes   no   3.0  3.0    no   2.0
# 4    Male  15.0    1.79   105.0            yes   no   2.0  1.0    no   2.0
#
#    SCC  FAF  TUE        CALC                 MTRANS              Obesity  \
# 0   no  0.0  1.0          no  Public_Transportation        Normal_Weight
# 1  yes  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight
# 2   no  2.0  1.0  Frequently  Public_Transportation        Normal_Weight
# 3   no  2.0  0.0  Frequently                Walking   Overweight_Level_I
# 4   no  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II
#
#   Age Group is Teen
# 0     Child     yes
# 1     Child     yes
# 2     Child     yes
# 3     Child     yes
# 4     Child     yes

# %% [markdown]
# # Merging DataFrames

# %% [markdown]
# ## merging dataframes is similar to joins in sql
# ### inner join
# ### outer join
# ### left join
# ### right join

# %%
df1 = pd.DataFrame(
    {
        "id": [1,2,3,4],
        "name": ["Abhinesh","KrishnaPriya","A","K"]
    }
)
df2 = pd.DataFrame(
    {
        "id": [3,4,5,6],
        "skill": ["Scientist","Artist","Engineer","Teacher"]
    }
)
inner_join = pd.merge(df1,df2, how='inner', on="id") #on is the primary key
print(inner_join)
outer_join = pd.merge(df1,df2, how='outer', on="id")
print(outer_join)
left_join = pd.merge(df1,df2, how='left', on="id")
print(left_join)
right_join = pd.merge(df1,df2, how='right', on="id")
print(right_join)
# Out:
#    id name      skill
# 0   3    A  Scientist
# 1   4    K     Artist
#    id          name      skill
# 0   1      Abhinesh        NaN
# 1   2  KrishnaPriya        NaN
# 2   3             A  Scientist
# 3   4             K     Artist
# 4   5           NaN   Engineer
# 5   6           NaN    Teacher
#    id          name      skill
# 0   1      Abhinesh        NaN
# 1   2  KrishnaPriya        NaN
# 2   3             A  Scientist
# 3   4             K     Artist
#    id name      skill
# 0   3    A  Scientist
# 1   4    K     Artist
# 2   5  NaN   Engineer
# 3   6  NaN    Teacher

# %% [markdown]
# ## Sometime the columnname  maybe different so,

# %%
df1 = pd.DataFrame(
    {
        "id1": [1,2,3,4],
        "name": ["Abhinesh","KrishnaPriya","A","K"]
    }
)
df2 = pd.DataFrame(
    {
        "id2": [3,4,5,6],
        "skill": ["Scientist","Artist","Engineer","Teacher"]
    }
)
inner_join = pd.merge(df1,df2, how='inner', left_on="id1", right_on="id2") # left_on is df1's primary key and right_on is df2's primary key
print(inner_join)
outer_join = pd.merge(df1,df2, how='outer', left_on="id1", right_on="id2")
print(outer_join)
left_join = pd.merge(df1,df2, how='left', left_on="id1", right_on="id2")
print(left_join)
right_join = pd.merge(df1,df2, how='right', left_on="id1", right_on="id2")
print(right_join)
# Out:
#    id1 name  id2      skill
# 0    3    A    3  Scientist
# 1    4    K    4     Artist
#    id1          name  id2      skill
# 0  1.0      Abhinesh  NaN        NaN
# 1  2.0  KrishnaPriya  NaN        NaN
# 2  3.0             A  3.0  Scientist
# 3  4.0             K  4.0     Artist
# 4  NaN           NaN  5.0   Engineer
# 5  NaN           NaN  6.0    Teacher
#    id1          name  id2      skill
# 0    1      Abhinesh  NaN        NaN
# 1    2  KrishnaPriya  NaN        NaN
# 2    3             A  3.0  Scientist
# 3    4             K  4.0     Artist
#    id1 name  id2      skill
# 0  3.0    A    3  Scientist
# 1  4.0    K    4     Artist
# 2  NaN  NaN    5   Engineer
# 3  NaN  NaN    6    Teacher

# %% [markdown]
# # Concatenating DataFrams
# ### its not merging where we need primary key, it just concatenates by vertically stacking or fusing horizontally

# %%
concated_df = pd.concat([df1, df2], axis=0)
# axis=0 is vertical Stacking while 1 is horizontal
print(concated_df)
# Out:
#    id1          name  id2      skill
# 0  1.0      Abhinesh  NaN        NaN
# 1  2.0  KrishnaPriya  NaN        NaN
# 2  3.0             A  NaN        NaN
# 3  4.0             K  NaN        NaN
# 0  NaN           NaN  3.0  Scientist
# 1  NaN           NaN  4.0     Artist
# 2  NaN           NaN  5.0   Engineer
# 3  NaN           NaN  6.0    Teacher

# %%
# since it is taking previous index, to assign a new index
concated_df = pd.concat([df1,df2], axis = 0, ignore_index = True)
print(concated_df)
# Out:
#    id1          name  id2      skill
# 0  1.0      Abhinesh  NaN        NaN
# 1  2.0  KrishnaPriya  NaN        NaN
# 2  3.0             A  NaN        NaN
# 3  4.0             K  NaN        NaN
# 4  NaN           NaN  3.0  Scientist
# 5  NaN           NaN  4.0     Artist
# 6  NaN           NaN  5.0   Engineer
# 7  NaN           NaN  6.0    Teacher

# %%
# horizontal merge
concated_hdf = pd.concat([df1,df2], axis = 1)
print(concated_hdf)
# Out:
#    id1          name  id2      skill
# 0    1      Abhinesh    3  Scientist
# 1    2  KrishnaPriya    4     Artist
# 2    3             A    5   Engineer
# 3    4             K    6    Teacher

# %%
# multilevel indexing
concated_df = pd.concat([df1,df2], axis = 0, keys=["dataF1", "dataF2"])
print(concated_df)
# Out:
#           id1          name  id2      skill
# dataF1 0  1.0      Abhinesh  NaN        NaN
#        1  2.0  KrishnaPriya  NaN        NaN
#        2  3.0             A  NaN        NaN
#        3  4.0             K  NaN        NaN
# dataF2 0  NaN           NaN  3.0  Scientist
#        1  NaN           NaN  4.0     Artist
#        2  NaN           NaN  5.0   Engineer
#        3  NaN           NaN  6.0    Teacher

# %% [markdown]
# # Handling Null, NaN values

# %%
concated_df.isna() # print is a value is null/nan or not in df format itself
# Out:
#             id1   name    id2  skill
# dataF1 0  False  False   True   True
#        1  False  False   True   True
#        2  False  False   True   True
#        3  False  False   True   True
# dataF2 0   True   True  False  False
#        1   True   True  False  False
#        2   True   True  False  False
#        3   True   True  False  False

# %%
concated_df.notna() # opposit of na
# Out:
#             id1   name    id2  skill
# dataF1 0   True   True  False  False
#        1   True   True  False  False
#        2   True   True  False  False
#        3   True   True  False  False
# dataF2 0  False  False   True   True
#        1  False  False   True   True
#        2  False  False   True   True
#        3  False  False   True   True

# %%
concated_df.isna().sum()
# Out:
# id1      4
# name     4
# id2      4
# skill    4
# dtype: int64

# %%
concated_df.notna().sum()
# Out:
# id1      4
# name     4
# id2      4
# skill    4
# dtype: int64

# %%
obesity_data.isna().sum() # no null data in obesity
# Out:
# Gender            0
# Age               0
# Height            0
# Weight            0
# family_history    0
# FAVC              0
# FCVC              0
# NCP               0
# SMOKE             0
# CH2O              0
# SCC               0
# FAF               0
# TUE               0
# CALC              0
# MTRANS            0
# Obesity           0
# Age Group         0
# is Teen           0
# dtype: int64

# %%
obesity_data.notna().sum()
# Out:
# Gender            2111
# Age               2111
# Height            2111
# Weight            2111
# family_history    2111
# FAVC              2111
# FCVC              2111
# NCP               2111
# SMOKE             2111
# CH2O              2111
# SCC               2111
# FAF               2111
# TUE               2111
# CALC              2111
# MTRANS            2111
# Obesity           2111
# Age Group         2111
# is Teen           2111
# dtype: int64

# %% [markdown]
# ## Putting in some null value in obesity

# %%
obesity_data.loc[20:30,'Age'] = np.nan # np nan nummber
obesity_data.loc[50:100,"SMOKE"] = np.nan
obesity_data.loc[500:520, "family_history"] = np.nan

# %%
obesity_data.sample(30)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 1529    Male  41.000000  1.750000  116.594351            yes  yes  2.000000
# 1466    Male  21.682636  1.818641  105.496975            yes  yes  2.078082
# 52    Female  23.000000  1.640000   52.000000             no  yes  3.000000
# 210     Male  20.000000  1.800000  114.000000            yes  yes  2.000000
# 478     Male  19.000000  1.690000   65.000000             no  yes  2.000000
# 1710    Male  23.360307  1.610647  100.642257            yes  yes  2.997524
# 481     Male  18.000000  1.740000   64.000000            yes  yes  3.000000
# 61      Male  20.000000  1.650000   58.000000            NaN  yes  2.000000
# 1372    Male  20.580984  1.798354  103.705418            yes  yes  2.000000
# 340     Male  21.000000  1.800000   72.000000             no  yes  3.000000
# 849     Male  21.701643  1.896073   90.524460            yes  yes  2.427689
# 312   Female  16.000000  1.600000   57.000000             no  yes  3.000000
# 1015    Male  21.808159  1.650000   80.000000            yes  yes  2.000000
# 539   Female  18.540535  1.564568   41.397378             no  yes  2.658112
# 1499    Male  23.246702  1.652971   93.310284            yes  yes  1.368978
# 764     Male  21.000000  1.620000   70.000000             no  yes  2.000000
# 1350    Male  20.491475  1.975663  120.702935            yes  yes  2.000000
# 514   Female  22.142432  1.596110   42.848033            NaN   no  3.000000
# 287   Female  18.000000  1.600000   58.000000            yes  yes  2.000000
# 70    Female  23.000000  1.650000   80.000000            yes  yes  2.000000
# 263     Male  23.000000  1.740000   53.000000             no  yes  2.000000
# 930   Female  21.009437  1.606810   67.773914            yes  yes  2.000000
# 1994  Female  21.282238  1.748951  133.662583            yes  yes  3.000000
# 229     Male  32.000000  1.750000  120.000000            yes   no  3.000000
# 307   Female  23.000000  1.590000   48.000000            yes  yes  2.000000
# 1296  Female  37.965430  1.560199   80.000000            yes  yes  2.533605
# 938   Female  21.028500  1.742364   78.664618            yes  yes  2.780699
# 1960  Female  25.950898  1.649867  104.791035            yes  yes  3.000000
# 78    Female  23.000000  1.650000   90.000000            yes  yes  2.000000
# 1084    Male  23.000000  1.774330   90.000000            yes  yes  2.116432
#
#            NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 1529  2.831771   Sometimes    no  1.725226   no  0.356288  0.000000
# 1466  3.000000   Sometimes    no  2.895614   no  0.062750  0.261793
# 52    1.000000   Sometimes   NaN  2.000000   no  2.000000  2.000000
# 210   3.000000  Frequently    no  2.000000   no  0.000000  1.000000
# 478   3.000000  Frequently    no  1.000000   no  1.000000  1.000000
# 1710  1.154318   Sometimes    no  1.238057   no  1.129300  1.665621
# 481   4.000000   Sometimes    no  1.000000  yes  2.000000  0.000000
# 61    3.000000   Sometimes   NaN  2.000000   no  3.000000  1.000000
# 1372  3.000000   Sometimes    no  2.401315   no  2.891986  0.000000
# 340   3.000000   Sometimes    no  2.000000   no  1.000000  1.000000
# 849   3.715306   Sometimes    no  2.876096   no  1.815768  0.426465
# 312   3.000000   Sometimes    no  1.000000   no  3.000000  0.000000
# 1015  3.000000   Sometimes    no  2.000000   no  0.826609  2.000000
# 539   1.000000   Sometimes    no  1.298165   no  0.000000  1.639326
# 1499  3.000000   Sometimes    no  1.953152   no  0.104707  0.221830
# 764   1.000000          no    no  3.000000   no  1.000000  0.000000
# 1350  3.000000   Sometimes    no  3.000000   no  0.767013  1.000000
# 514   2.581015  Frequently    no  2.654702   no  0.902095  0.000000
# 287   3.000000   Sometimes    no  3.000000   no  3.000000  0.000000
# 70    3.000000      Always   NaN  2.000000   no  0.000000  2.000000
# 263   3.000000  Frequently    no  1.000000   no  3.000000  2.000000
# 930   3.156309          no    no  3.000000   no  1.179592  0.086868
# 1994  3.000000   Sometimes    no  2.247979   no  1.609938  0.849236
# 229   3.000000   Sometimes    no  3.000000   no  0.000000  2.000000
# 307   1.000000  Frequently    no  1.000000   no  0.000000  2.000000
# 1296  1.271624   Sometimes    no  1.893691   no  1.296535  0.000000
# 938   1.101404   Sometimes    no  1.579207   no  1.153775  0.000000
# 1960  3.000000   Sometimes    no  2.535629   no  0.152713  0.770200
# 78    3.000000   Sometimes   NaN  3.000000   no  0.000000  1.000000
# 1084  3.000000   Sometimes    no  1.002292   no  0.000000  1.066708
#
#            CALC                 MTRANS              Obesity
# 1529  Sometimes             Automobile      Obesity_Type_II
# 1466  Sometimes  Public_Transportation       Obesity_Type_I
# 52           no  Public_Transportation        Normal_Weight
# 210          no  Public_Transportation      Obesity_Type_II
# 478   Sometimes  Public_Transportation        Normal_Weight
# 1710         no  Public_Transportation      Obesity_Type_II
# 481   Sometimes  Public_Transportation        Normal_Weight
# 61    Sometimes  Public_Transportation        Normal_Weight
# 1372         no  Public_Transportation       Obesity_Type_I
# 340          no  Public_Transportation        Normal_Weight
# 849   Sometimes  Public_Transportation   Overweight_Level_I
# 312          no  Public_Transportation        Normal_Weight
# 1015         no  Public_Transportation  Overweight_Level_II
# 539   Sometimes  Public_Transportation  Insufficient_Weight
# 1499         no             Automobile       Obesity_Type_I
# 764   Sometimes  Public_Transportation   Overweight_Level_I
# 1350  Sometimes  Public_Transportation       Obesity_Type_I
# 514          no  Public_Transportation  Insufficient_Weight
# 287          no  Public_Transportation        Normal_Weight
# 70           no  Public_Transportation  Overweight_Level_II
# 263          no  Public_Transportation  Insufficient_Weight
# 930   Sometimes  Public_Transportation   Overweight_Level_I
# 1994  Sometimes  Public_Transportation     Obesity_Type_III
# 229          no             Automobile      Obesity_Type_II
# 307   Sometimes  Public_Transportation        Normal_Weight
# 1296  Sometimes             Automobile       Obesity_Type_I
# 938   Sometimes  Public_Transportation   Overweight_Level_I
# 1960  Sometimes  Public_Transportation     Obesity_Type_III
# 78           no  Public_Transportation       Obesity_Type_I
# 1084  Sometimes  Public_Transportation  Overweight_Level_II

# %% [markdown]
# ## Managing the null

# %%
obesity_data.fillna(0) # fill all nan with 0 does not change the df
obesity_data.fillna(0, inplace = True) # changes the df
print(obesity_data.loc[500:510])
print(obesity_data.sample(10))
# Out:
#      Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 500  Female  26.000000  1.622397  110.792630              0  yes  3.000000
# 501  Female  21.853826  1.755643  137.796884              0  yes  3.000000
# 502  Female  21.900120  1.843419  165.057269              0  yes  3.000000
# 503  Female  18.306615  1.745600  133.034410              0  yes  3.000000
# 504  Female  26.000000  1.630927  111.485516              0  yes  3.000000
# 505  Female  26.000000  1.629191  104.826776              0  yes  3.000000
# 506  Female  21.849705  1.770612  133.963349              0  yes  3.000000
# 507    Male  19.799054  1.743702   54.927529              0  yes  2.000000
# 508    Male  17.188754  1.771915   55.695036              0  yes  2.000000
# 509    Male  22.285024  1.753760   55.879263              0  yes  2.450218
# 510  Female  22.000000  1.675446   51.154201              0  yes  3.000000
#
#           NCP        CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 500  3.000000   Sometimes    no  2.704507  no  0.000000  0.294990  Sometimes
# 501  3.000000   Sometimes    no  2.184707  no  1.978631  0.838957  Sometimes
# 502  3.000000   Sometimes    no  2.406541  no  0.100320  0.479221  Sometimes
# 503  3.000000   Sometimes    no  2.984323  no  1.586525  0.625350  Sometimes
# 504  3.000000   Sometimes    no  2.444125  no  0.000000  0.265790  Sometimes
# 505  3.000000   Sometimes    no  2.654702  no  0.000000  0.555468  Sometimes
# 506  3.000000   Sometimes    no  2.825629  no  1.399183  0.928972  Sometimes
# 507  3.289260   Sometimes    no  2.847264  no  1.680844  2.000000  Sometimes
# 508  4.000000   Sometimes    no  2.884033  no  2.000000  1.340107  Sometimes
# 509  3.995147   Sometimes    no  2.147746  no  2.000000  0.589980  Sometimes
# 510  3.000000  Frequently    no  2.815293  no  1.978631  1.000000         no
#
#                     MTRANS              Obesity
# 500  Public_Transportation     Obesity_Type_III
# 501  Public_Transportation     Obesity_Type_III
# 502  Public_Transportation     Obesity_Type_III
# 503  Public_Transportation     Obesity_Type_III
# 504  Public_Transportation     Obesity_Type_III
# 505  Public_Transportation     Obesity_Type_III
# 506  Public_Transportation     Obesity_Type_III
# 507  Public_Transportation  Insufficient_Weight
# 508  Public_Transportation  Insufficient_Weight
# 509  Public_Transportation  Insufficient_Weight
# 510  Public_Transportation  Insufficient_Weight
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 1381  Female  33.226808  1.557943   77.647716            yes  yes  2.020910
# 20      Male   0.000000  1.650000   80.000000            yes   no  2.000000
# 965   Female  17.258130  1.600184   65.000000            yes  yes  2.749629
# 1747    Male  29.981494  1.773181  112.348722            yes  yes  1.947495
# 1630    Male  30.403205  1.696365  102.815983            yes  yes  2.791660
# 1322  Female  23.000000  1.630357   83.101100            yes  yes  2.977585
# 1865  Female  21.633056  1.754174  133.783955            yes  yes  3.000000
# 123     Male  24.000000  1.660000   67.000000            yes  yes  3.000000
# 1943  Female  21.391371  1.730636  131.902591            yes  yes  3.000000
# 48    Female  20.000000  1.660000   60.000000            yes   no  3.000000
#
#            NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE       CALC  \
# 1381  2.093831  Sometimes    no  1.506518   no  0.000000  0.000000  Sometimes
# 20    3.000000  Sometimes    no  2.000000   no  3.000000  2.000000         no
# 965   2.298612  Sometimes    no  2.000000  yes  0.547515  1.619473  Sometimes
# 1747  3.000000  Sometimes    no  2.042073   no  0.000000  0.618087  Sometimes
# 1630  2.132290  Sometimes    no  1.254589   no  0.652736  1.040713         no
# 1322  1.630506  Sometimes    no  2.839319   no  1.091474  0.889517         no
# 1865  3.000000  Sometimes    no  1.945950   no  1.493018  0.906611  Sometimes
# 123   1.000000  Sometimes    no  2.000000   no  1.000000  0.000000         no
# 1943  3.000000  Sometimes    no  1.419136   no  1.700889  0.930888  Sometimes
# 48    3.000000  Sometimes    no  2.000000   no  1.000000  0.000000  Sometimes
#
#                      MTRANS              Obesity
# 1381             Automobile       Obesity_Type_I
# 20                  Walking  Overweight_Level_II
# 965   Public_Transportation   Overweight_Level_I
# 1747             Automobile      Obesity_Type_II
# 1630  Public_Transportation      Obesity_Type_II
# 1322  Public_Transportation       Obesity_Type_I
# 1865  Public_Transportation     Obesity_Type_III
# 123   Public_Transportation        Normal_Weight
# 1943  Public_Transportation     Obesity_Type_III
# 48                  Walking        Normal_Weight

# %%
obesity_data.loc[20:30,'Age'] = np.nan # np nan nummber
obesity_data.loc[50:55,"SMOKE"] = np.nan
obesity_data.loc[60:68, "family_history"] = np.nan
print(obesity_data.loc[20:100])
# Out:
#      Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 20     Male   NaN    1.65    80.0            yes   no   2.0  3.0   Sometimes
# 21   Female   NaN    1.69    87.0            yes  yes   3.0  1.0   Sometimes
# 22   Female   NaN    1.65    60.0            yes  yes   3.0  3.0   Sometimes
# 23   Female   NaN    1.60    82.0            yes  yes   1.0  1.0   Sometimes
# 24     Male   NaN    1.85    68.0            yes  yes   2.0  3.0   Sometimes
# ..      ...   ...     ...     ...            ...  ...   ...  ...         ...
# 96   Female  23.0    1.66    60.0            yes   no   2.0  3.0   Sometimes
# 97   Female  21.0    1.52    42.0             no   no   3.0  1.0  Frequently
# 98   Female  21.0    1.52    42.0             no   no   3.0  1.0  Frequently
# 99     Male  23.0    1.72    70.0             no   no   2.0  3.0   Sometimes
# 100  Female  21.0    1.69    63.0             no  yes   3.0  1.0   Sometimes
#
#     SMOKE  CH2O SCC  FAF  TUE        CALC                 MTRANS  \
# 20     no   2.0  no  3.0  2.0          no                Walking
# 21    yes   2.0  no  0.0  0.0          no             Automobile
# 22     no   2.0  no  1.0  0.0   Sometimes             Automobile
# 23     no   2.0  no  0.0  2.0   Sometimes  Public_Transportation
# 24     no   2.0  no  0.0  1.0   Sometimes  Public_Transportation
# ..    ...   ...  ..  ...  ...         ...                    ...
# 96      0   2.0  no  3.0  0.0   Sometimes  Public_Transportation
# 97      0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
# 98      0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
# 99      0   2.0  no  3.0  1.0  Frequently  Public_Transportation
# 100     0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
#
#                  Obesity
# 20   Overweight_Level_II
# 21        Obesity_Type_I
# 22         Normal_Weight
# 23        Obesity_Type_I
# 24         Normal_Weight
# ..                   ...
# 96         Normal_Weight
# 97   Insufficient_Weight
# 98   Insufficient_Weight
# 99         Normal_Weight
# 100        Normal_Weight
#
# [81 rows x 17 columns]

# %%
obesity_data['Age'] = obesity_data['Age'].fillna(20) # change nan on age column only

# %%
obesity_data['Age'] = obesity_data['Age'].fillna(obesity_data['Age'].mean()) # filling nan with mean

# %%
obesity_data.sample(20)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 328     Male  19.000000  1.740000   74.000000            yes   no  3.000000
# 500   Female  26.000000  1.622397  110.792630              0  yes  3.000000
# 1096  Female  39.170029  1.688354   79.278896            yes  yes  3.000000
# 270     Male  23.000000  1.820000  107.000000             no  yes  2.000000
# 2063  Female  20.952737  1.730333  132.116491            yes  yes  3.000000
# 1720    Male  30.451174  1.758539  111.950413            yes  yes  1.067909
# 201   Female  41.000000  1.540000   80.000000            yes  yes  2.000000
# 63      Male  22.000000  1.680000   55.000000            NaN  yes  2.000000
# 1735    Male  26.734476  1.816197  119.622764            yes  yes  2.247037
# 1460    Male  23.000000  1.742500  105.028665            yes  yes  2.393837
# 262     Male  18.000000  1.740000   70.000000             no  yes  2.000000
# 946     Male  19.637203  1.814182   85.301029            yes  yes  2.923916
# 31    Female  31.000000  1.580000   68.000000            yes   no  2.000000
# 1983  Female  20.908785  1.700996  126.490236            yes  yes  3.000000
# 548   Female  19.314964  1.661403   49.932199             no  yes  2.205439
# 1915  Female  26.000000  1.616975  104.846218            yes  yes  3.000000
# 1154    Male  22.882558  1.793451   89.909259            yes  yes  1.899116
# 1917  Female  21.768153  1.764160  133.888629            yes  yes  3.000000
# 1193    Male  19.565496  1.705584   78.025625            yes   no  1.936479
# 473   Female  18.000000  1.630000   51.000000            yes  yes  1.000000
#
#            NCP        CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 328   1.000000   Sometimes    no  3.000000  no  3.000000  1.000000  Sometimes
# 500   3.000000   Sometimes    no  2.704507  no  0.000000  0.294990  Sometimes
# 1096  3.000000   Sometimes    no  2.994515  no  0.000000  0.000000         no
# 270   3.000000   Sometimes    no  3.000000  no  0.000000  1.000000  Sometimes
# 2063  3.000000   Sometimes    no  1.674061  no  1.683497  0.780199  Sometimes
# 1720  3.656401   Sometimes    no  1.984590  no  0.054238  0.000000  Sometimes
# 201   3.000000      Always    no  1.000000  no  0.000000  0.000000  Sometimes
# 63    3.000000   Sometimes     0  2.000000  no  0.000000  2.000000  Sometimes
# 1735  3.000000   Sometimes    no  2.718408  no  0.763595  0.000000  Sometimes
# 1460  3.000000   Sometimes    no  2.014990  no  0.978815  0.413220  Sometimes
# 262   3.000000   Sometimes    no  2.000000  no  1.000000  1.000000  Sometimes
# 946   3.335876   Sometimes    no  2.372444  no  1.305633  0.311436  Sometimes
# 31    1.000000   Sometimes    no  1.000000  no  1.000000  0.000000  Sometimes
# 1983  3.000000   Sometimes    no  1.242832  no  0.530925  0.575969  Sometimes
# 548   3.000000   Sometimes    no  1.530531  no  2.000000  1.000000  Sometimes
# 1915  3.000000   Sometimes    no  2.653563  no  0.000000  0.554150  Sometimes
# 1154  2.375026   Sometimes    no  1.398540  no  0.000000  1.365793  Sometimes
# 1917  3.000000   Sometimes    no  2.325020  no  1.441791  0.918468  Sometimes
# 1193  2.837388   Sometimes    no  2.159987  no  1.475772  0.646514  Sometimes
# 473   3.000000  Frequently    no  1.000000  no  1.000000  0.000000  Sometimes
#
#                      MTRANS              Obesity
# 328                 Walking        Normal_Weight
# 500   Public_Transportation     Obesity_Type_III
# 1096             Automobile  Overweight_Level_II
# 270   Public_Transportation       Obesity_Type_I
# 2063  Public_Transportation     Obesity_Type_III
# 1720             Automobile      Obesity_Type_II
# 201              Automobile       Obesity_Type_I
# 63               Automobile        Normal_Weight
# 1735  Public_Transportation      Obesity_Type_II
# 1460  Public_Transportation       Obesity_Type_I
# 262   Public_Transportation        Normal_Weight
# 946   Public_Transportation   Overweight_Level_I
# 31    Public_Transportation  Overweight_Level_II
# 1983  Public_Transportation     Obesity_Type_III
# 548   Public_Transportation  Insufficient_Weight
# 1915  Public_Transportation     Obesity_Type_III
# 1154  Public_Transportation  Overweight_Level_II
# 1917  Public_Transportation     Obesity_Type_III
# 1193  Public_Transportation  Overweight_Level_II
# 473   Public_Transportation        Normal_Weight

# %% [markdown]
# ## filling multiple column nulls

# %%
obesity_data.isna().sum()
# Out:
# Gender            0
# Age               0
# Height            0
# Weight            0
# family_history    9
# FAVC              0
# FCVC              0
# NCP               0
# CAEC              0
# SMOKE             6
# CH2O              0
# SCC               0
# FAF               0
# TUE               0
# CALC              0
# MTRANS            0
# Obesity           0
# dtype: int64

# %%
obesity_data.fillna({'SMOKE': 'no','family_history': 'no'})
obesity_data.fillna({'SMOKE': 'no','family_history': 'no'}, inplace = True)

# %%
obesity_data.isna().sum()
# Out:
# Gender             0
# Age               11
# Height             0
# Weight             0
# family_history     9
# FAVC               0
# FCVC               0
# NCP                0
# CAEC               0
# SMOKE              6
# CH2O               0
# SCC                0
# FAF                0
# TUE                0
# CALC               0
# MTRANS             0
# Obesity            0
# dtype: int64

# %%
obesity_data.loc[20:30,'Age'] = np.nan # np nan nummber
obesity_data.loc[50:55,"SMOKE"] = np.nan
obesity_data.loc[60:68, "family_history"] = np.nan
print(obesity_data.loc[20:100])
# Out:
#      Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 20     Male   NaN    1.65    80.0            yes   no   2.0  3.0   Sometimes
# 21   Female   NaN    1.69    87.0            yes  yes   3.0  1.0   Sometimes
# 22   Female   NaN    1.65    60.0            yes  yes   3.0  3.0   Sometimes
# 23   Female   NaN    1.60    82.0            yes  yes   1.0  1.0   Sometimes
# 24     Male   NaN    1.85    68.0            yes  yes   2.0  3.0   Sometimes
# ..      ...   ...     ...     ...            ...  ...   ...  ...         ...
# 96   Female  23.0    1.66    60.0            yes   no   2.0  3.0   Sometimes
# 97   Female  21.0    1.52    42.0             no   no   3.0  1.0  Frequently
# 98   Female  21.0    1.52    42.0             no   no   3.0  1.0  Frequently
# 99     Male  23.0    1.72    70.0             no   no   2.0  3.0   Sometimes
# 100  Female  21.0    1.69    63.0             no  yes   3.0  1.0   Sometimes
#
#     SMOKE  CH2O SCC  FAF  TUE        CALC                 MTRANS  \
# 20     no   2.0  no  3.0  2.0          no                Walking
# 21    yes   2.0  no  0.0  0.0          no             Automobile
# 22     no   2.0  no  1.0  0.0   Sometimes             Automobile
# 23     no   2.0  no  0.0  2.0   Sometimes  Public_Transportation
# 24     no   2.0  no  0.0  1.0   Sometimes  Public_Transportation
# ..    ...   ...  ..  ...  ...         ...                    ...
# 96      0   2.0  no  3.0  0.0   Sometimes  Public_Transportation
# 97      0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
# 98      0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
# 99      0   2.0  no  3.0  1.0  Frequently  Public_Transportation
# 100     0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
#
#                  Obesity
# 20   Overweight_Level_II
# 21        Obesity_Type_I
# 22         Normal_Weight
# 23        Obesity_Type_I
# 24         Normal_Weight
# ..                   ...
# 96         Normal_Weight
# 97   Insufficient_Weight
# 98   Insufficient_Weight
# 99         Normal_Weight
# 100        Normal_Weight
#
# [81 rows x 17 columns]

# %% [markdown]
# # Interpolate
# - it fill the nan with a value relative to neigbouring values on the same column

# %%
obesity_data['Age'] = obesity_data['Age'].fillna(obesity_data['Age'].interpolate())
obesity_data.loc[20:100]
# Out:
#      Gender        Age  Height  Weight family_history FAVC  FCVC  NCP  \
# 20     Male  23.666667    1.65    80.0            yes   no   2.0  3.0
# 21   Female  24.333333    1.69    87.0            yes  yes   3.0  1.0
# 22   Female  25.000000    1.65    60.0            yes  yes   3.0  3.0
# 23   Female  25.666667    1.60    82.0            yes  yes   1.0  1.0
# 24     Male  26.333333    1.85    68.0            yes  yes   2.0  3.0
# ..      ...        ...     ...     ...            ...  ...   ...  ...
# 96   Female  23.000000    1.66    60.0            yes   no   2.0  3.0
# 97   Female  21.000000    1.52    42.0             no   no   3.0  1.0
# 98   Female  21.000000    1.52    42.0             no   no   3.0  1.0
# 99     Male  23.000000    1.72    70.0             no   no   2.0  3.0
# 100  Female  21.000000    1.69    63.0             no  yes   3.0  1.0
#
#            CAEC SMOKE  CH2O SCC  FAF  TUE        CALC                 MTRANS  \
# 20    Sometimes    no   2.0  no  3.0  2.0          no                Walking
# 21    Sometimes   yes   2.0  no  0.0  0.0          no             Automobile
# 22    Sometimes    no   2.0  no  1.0  0.0   Sometimes             Automobile
# 23    Sometimes    no   2.0  no  0.0  2.0   Sometimes  Public_Transportation
# 24    Sometimes    no   2.0  no  0.0  1.0   Sometimes  Public_Transportation
# ..          ...   ...   ...  ..  ...  ...         ...                    ...
# 96    Sometimes     0   2.0  no  3.0  0.0   Sometimes  Public_Transportation
# 97   Frequently     0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
# 98   Frequently     0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
# 99    Sometimes     0   2.0  no  3.0  1.0  Frequently  Public_Transportation
# 100   Sometimes     0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
#
#                  Obesity
# 20   Overweight_Level_II
# 21        Obesity_Type_I
# 22         Normal_Weight
# 23        Obesity_Type_I
# 24         Normal_Weight
# ..                   ...
# 96         Normal_Weight
# 97   Insufficient_Weight
# 98   Insufficient_Weight
# 99         Normal_Weight
# 100        Normal_Weight
#
# [81 rows x 17 columns]

# %% [markdown]
# ## limit
# - we are setting limit to how manu nan it can change

# %%
obesity_data.loc[20:30,'Age'] = np.nan # np nan nummber
obesity_data.loc[50:55,"SMOKE"] = np.nan
obesity_data.loc[60:68, "family_history"] = np.nan
print(obesity_data.loc[20:100])
# Out:
#      Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 20     Male   NaN    1.65    80.0            yes   no   2.0  3.0   Sometimes
# 21   Female   NaN    1.69    87.0            yes  yes   3.0  1.0   Sometimes
# 22   Female   NaN    1.65    60.0            yes  yes   3.0  3.0   Sometimes
# 23   Female   NaN    1.60    82.0            yes  yes   1.0  1.0   Sometimes
# 24     Male   NaN    1.85    68.0            yes  yes   2.0  3.0   Sometimes
# ..      ...   ...     ...     ...            ...  ...   ...  ...         ...
# 96   Female  23.0    1.66    60.0            yes   no   2.0  3.0   Sometimes
# 97   Female  21.0    1.52    42.0             no   no   3.0  1.0  Frequently
# 98   Female  21.0    1.52    42.0             no   no   3.0  1.0  Frequently
# 99     Male  23.0    1.72    70.0             no   no   2.0  3.0   Sometimes
# 100  Female  21.0    1.69    63.0             no  yes   3.0  1.0   Sometimes
#
#     SMOKE  CH2O SCC  FAF  TUE        CALC                 MTRANS  \
# 20     no   2.0  no  3.0  2.0          no                Walking
# 21    yes   2.0  no  0.0  0.0          no             Automobile
# 22     no   2.0  no  1.0  0.0   Sometimes             Automobile
# 23     no   2.0  no  0.0  2.0   Sometimes  Public_Transportation
# 24     no   2.0  no  0.0  1.0   Sometimes  Public_Transportation
# ..    ...   ...  ..  ...  ...         ...                    ...
# 96      0   2.0  no  3.0  0.0   Sometimes  Public_Transportation
# 97      0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
# 98      0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
# 99      0   2.0  no  3.0  1.0  Frequently  Public_Transportation
# 100     0   1.0  no  0.0  0.0   Sometimes  Public_Transportation
#
#                  Obesity
# 20   Overweight_Level_II
# 21        Obesity_Type_I
# 22         Normal_Weight
# 23        Obesity_Type_I
# 24         Normal_Weight
# ..                   ...
# 96         Normal_Weight
# 97   Insufficient_Weight
# 98   Insufficient_Weight
# 99         Normal_Weight
# 100        Normal_Weight
#
# [81 rows x 17 columns]

# %%
obesity_data['Age'].isna().sum()
# Out:
# np.int64(11)

# %%
obesity_data['Age'] =obesity_data['Age'].fillna(0, limit = 3)

# %%
print(obesity_data.isna().sum())
print(obesity_data.shape)
# Out:
# Gender            0
# Age               8
# Height            0
# Weight            0
# family_history    9
# FAVC              0
# FCVC              0
# NCP               0
# CAEC              0
# SMOKE             6
# CH2O              0
# SCC               0
# FAF               0
# TUE               0
# CALC              0
# MTRANS            0
# Obesity           0
# dtype: int64
# (2111, 17)

# %% [markdown]
# ## drop rows with null

# %%
obesity_data.dropna() # does not change the df
obesity_data.dropna(inplace = True)

# %%
print(obesity_data.isna().sum())
print(obesity_data.shape)
# Out:
# Gender            0
# Age               0
# Height            0
# Weight            0
# family_history    0
# FAVC              0
# FCVC              0
# NCP               0
# CAEC              0
# SMOKE             0
# CH2O              0
# SCC               0
# FAF               0
# TUE               0
# CALC              0
# MTRANS            0
# Obesity           0
# dtype: int64
# (2088, 17)

# %% [markdown]
# # Group By

# %%
print(obesity_data.groupby('Gender').count())
print(obesity_data.groupby('Gender')["Height"].mean())
print(obesity_data.groupby('Gender')["Weight"].median())
print(obesity_data.groupby('Gender')["Weight"].agg(['sum','mean']))
# Out:
#          Age  Height  Weight  family_history  FAVC  FCVC   NCP  CAEC  SMOKE  \
# Gender
# Female  1033    1033    1033            1033  1033  1033  1033  1033   1033
# Male    1055    1055    1055            1055  1055  1055  1055  1055   1055
#
#         CH2O   SCC   FAF   TUE  CALC  MTRANS  Obesity
# Gender
# Female  1033  1033  1033  1033  1033    1033     1033
# Male    1055  1055  1055  1055  1055    1055     1055
# Gender
# Female    1.643707
# Male      1.759281
# Name: Height, dtype: float64
# Gender
# Female    78.055968
# Male      89.994351
# Name: Weight, dtype: float64
#                  sum       mean
# Gender
# Female  85271.865833  82.547789
# Male    95995.802872  90.991282
